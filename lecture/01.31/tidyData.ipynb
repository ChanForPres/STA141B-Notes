# %%
import pandas as pd
import numpy as np
dogSet1 = pd.read_csv('../../data/dogs_full.csv')
h1 = dogSet1.head()
h1
# Out:
#                     breed     group  datadog  popularity_all  popularity  \
# 0           Border Collie   herding     3.64              45        39.0
# 1          Border Terrier   terrier     3.61              80        61.0
# 2                Brittany  sporting     3.54              30        30.0
# 3           Cairn Terrier   terrier     3.53              59        48.0
# 4  Welsh Springer Spaniel  sporting     3.34             130        81.0
#
#    lifetime_cost  intelligence_rank  longevity  ailments  price  food_cost  \
# 0        20143.0                1.0      12.52       2.0  623.0      324.0
# 1        22638.0               30.0      14.00       0.0  833.0      324.0
# 2        22589.0               19.0      12.92       0.0  618.0      466.0
# 3        21992.0               35.0      13.84       2.0  435.0      324.0
# 4        20224.0               31.0      12.49       1.0  750.0      324.0
#
#   grooming    kids  megarank_kids  megarank    size  weight  height
# ...

# %%
dogSet1.shape
dogSet1.keys()
# Out:
# Index(['breed', 'group', 'datadog', 'popularity_all', 'popularity',
#        'lifetime_cost', 'intelligence_rank', 'longevity', 'ailments', 'price',
#        'food_cost', 'grooming', 'kids', 'megarank_kids', 'megarank', 'size',
#        'weight', 'height'],
#       dtype='object')

# %%
dogSet2 = pd.read_csv('../../data/dogs_full.csv',index_col=0)
h2 = dogSet2.head()
dogSet.group == dogSet2['group']
# Out:
# breed
# Border Collie                         True
# Border Terrier                        True
# Brittany                              True
# Cairn Terrier                         True
# Welsh Springer Spaniel                True
# English Cocker Spaniel                True
# Cocker Spaniel                        True
# Papillon                              True
# Australian Cattle Dog                 True
# Shetland Sheepdog                     True
# Siberian Husky                        True
# Lhasa Apso                            True
# Affenpinscher                         True
# Dachshund                             True
# Miniature Schnauzer                   True
# Chihuahua                             True
# Australian Terrier                    True
# Whippet                               True
# English Springer Spaniel              True
# West Highland White Terrier           True
# Bedlington Terrier                    True
# Poodle                                True
# ...

# %%
dogSet.shape
# Out:
# (172, 18)

# %%
col1 = dogSet['breed']
dogSet.columns
cols=[]
arr1 = [dogSet[i] for i in dogSet.columns]
narr1 = np.array(arr1)
narr1.shape
# Out:
# (18, 172)

# %%
narr1[1][0]
# Out:
# 'herding'

# %%
h1.iloc[1]
# Out:
# breed                Border Terrier
# group                       terrier
# datadog                        3.61
# popularity_all                   80
# popularity                       61
# lifetime_cost                 22638
# intelligence_rank                30
# longevity                        14
# ailments                          0
# price                           833
# food_cost                       324
# grooming                     weekly
# kids                           high
# megarank_kids                     2
# megarank                          1
# size                          small
# weight                         13.5
# height                          NaN
# Name: 1, dtype: object

# %%
h1.loc[0]
# Out:
# breed                Border Collie
# group                      herding
# datadog                       3.64
# popularity_all                  45
# popularity                      39
# lifetime_cost                20143
# intelligence_rank                1
# longevity                    12.52
# ailments                         2
# price                          623
# food_cost                      324
# grooming                    weekly
# kids                           low
# megarank_kids                    1
# megarank                        29
# size                        medium
# weight                         NaN
# height                          20
# Name: 0, dtype: object

# %%
narr2 = np.random.rand(10 ** 5, 5)
>>> row = 50000
>>> col = 3
narr2
# Out:
# array([[0.67687853, 0.10589285, 0.25244005, 0.54119357, 0.56984114],
#        [0.50649856, 0.4963285 , 0.89966653, 0.90103815, 0.51548093],
#        [0.93746614, 0.44257073, 0.16610292, 0.70099769, 0.24162378],
#        ...,
#        [0.61905892, 0.77127697, 0.09578521, 0.00770874, 0.41474093],
#        [0.32848267, 0.914907  , 0.1373144 , 0.79642216, 0.85640686],
#        [0.13632644, 0.4431674 , 0.88994317, 0.01430865, 0.81023333]])

# %%
narr2.shape
# Out:
# (100000, 5)

# %%
# %timeit narr2[row, col]
# Out:
# 201 ns ± 3.86 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit dogSet1['breed']
# Out:
# 1.44 µs ± 28.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
dogSet1.shape
# Out:
# (172, 18)

# %%
type(dogSet1.isna())
# Out:
# pandas.core.frame.DataFrame

# %%
dogSet1.isna() == dogSet1.isnull()
# Out:
#      breed  group  datadog  popularity_all  popularity  lifetime_cost  \
# 0     True   True     True            True        True           True
# 1     True   True     True            True        True           True
# 2     True   True     True            True        True           True
# 3     True   True     True            True        True           True
# 4     True   True     True            True        True           True
# 5     True   True     True            True        True           True
# 6     True   True     True            True        True           True
# 7     True   True     True            True        True           True
# 8     True   True     True            True        True           True
# 9     True   True     True            True        True           True
# 10    True   True     True            True        True           True
# 11    True   True     True            True        True           True
# ...

# %%
dogSet1.head()
dogSet1.head()['datadog'] +=100
# Out:
# /Users/channy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dogSet1.head()
# Out:
#                     breed     group  datadog  popularity_all  popularity  \
# 0           Border Collie   herding     3.64              45        39.0
# 1          Border Terrier   terrier     3.61              80        61.0
# 2                Brittany  sporting     3.54              30        30.0
# 3           Cairn Terrier   terrier     3.53              59        48.0
# 4  Welsh Springer Spaniel  sporting     3.34             130        81.0
#
#    lifetime_cost  intelligence_rank  longevity  ailments  price  food_cost  \
# 0        20143.0                1.0      12.52       2.0  623.0      324.0
# 1        22638.0               30.0      14.00       0.0  833.0      324.0
# 2        22589.0               19.0      12.92       0.0  618.0      466.0
# 3        21992.0               35.0      13.84       2.0  435.0      324.0
# 4        20224.0               31.0      12.49       1.0  750.0      324.0
#
#   grooming    kids  megarank_kids  megarank    size  weight  height
# ...

# %%
dogSet1.loc['*','datadog']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2601             try:
# -> 2602                 return self._engine.get_loc(key)
#    2603             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '*'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-9850d16f3130> in <module>
# ----> 1 dogSet1.loc['*','datadog']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
# ...
