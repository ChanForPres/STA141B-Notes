# %%
import pandas as pd
import numpy as np
import random
df1 = pd.read_csv('uk-500.csv')

# %%
df1.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
df1['id'] = [random.randint(0,1000) for x in range(df1.shape[0])]

# %%
[df1['id'][i] == 0 for i in range(500)]
val = df1['first_name'] =='Aleshia'

# %%
df1[['first_name','last_name']].head()
# Out:
#   first_name   last_name
# 0    Aleshia  Tomkiewicz
# 1       Evan   Zigomalas
# 2     France     Andrade
# 3    Ulysses   Mcwalters
# 4     Tyisha      Veness

# %%
df1.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
df1.iloc[[0],-1] # every row, last col
# Out:
# 0    793
# Name: id, dtype: int64

# %%
df1.iloc[:,4] 
df1.iloc[[1,2,3],[3,4,5]]
df1.iloc[:,:2]
pass

# %%
df1.loc[0:3,'address']
df2 = df1.set_index('first_name')
df2.head()
# Out:
#              last_name             company_name            address  \
# first_name
# Aleshia     Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# Evan         Zigomalas       Cap Gemini America        5 Binney St
# France         Andrade      Elliott, John W Esq       8 Moor Place
# Ulysses      Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# Tyisha          Veness           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# first_name
# Aleshia                  St. Stephens Ward             Kent   CT2 7PP
# Evan                            Abbey Ward  Buckinghamshire  HP11 2AX
# France      East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Ulysses                 Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Tyisha          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# first_name
# ...

# %%
# inplace = Modify the DataFrame in place (do not create a new object).
df2.reset_index()
df2.loc[['Aleshia','Eric'],['last_name','address']]
df2.loc['Aleshia':'Tyisha','city':'phone2']
# Out:
#                                       city           county    postal  \
# first_name
# Aleshia                  St. Stephens Ward             Kent   CT2 7PP
# Evan                            Abbey Ward  Buckinghamshire  HP11 2AX
# France      East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Ulysses                 Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Tyisha          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2
# first_name
# Aleshia     01835-703597  01944-369967
# Evan        01937-864715  01714-737668
# France      01347-368222  01935-821636
# Ulysses     01912-771311  01302-601380
# Tyisha      01547-429341  01290-367248

# %%
df2.set_index('county',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-5cc013aad241> in <module>
# ----> 1 df2.set_index('county',inplace=True)
#       2 df2
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4154
#    4155         if missing:
# -> 4156             raise KeyError('{}'.format(missing))
#    4157
#    4158         if inplace:
#
# KeyError: "['county']"

# %%
df2.shape
df2.loc['Kent'].shape
# Out:
# (500, 10)

# %%
df2.loc['Kent']
df2.head()
# Out:
#                   last_name             company_name            address  \
# county
# Kent             Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# Buckinghamshire   Zigomalas       Cap Gemini America        5 Binney St
# Bournemouth         Andrade      Elliott, John W Esq       8 Moor Place
# Lincolnshire      Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# West Midlands        Veness           Champagne Room  5396 Forth Street
#
#                                            city    postal        phone1  \
# county
# Kent                          St. Stephens Ward   CT2 7PP  01835-703597
# Buckinghamshire                      Abbey Ward  HP11 2AX  01937-864715
# Bournemouth      East Southbourne and Tuckton W   BH6 3BE  01347-368222
# Lincolnshire                 Hawerby cum Beesby  DN36 5RP  01912-771311
# West Midlands        Greets Green and Lyng Ward   B70 9DT  01547-429341
#
#                        phone2                       email  \
# county
# ...

# %%
df2.columns[0]
df1.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
df2.loc[df2['last_name']=='Zigomalas']
df2.loc[df2['last_name']=='Dubberly']
df1.loc[df1['first_name']=='Erasmo',]
df1.loc[df1['first_name']=='Erasmo',['company_name','city']]
# Out:
#            company_name              city
# 233  Active Air Systems  Darton West Ward
# 393            Pan Optx       Sunningdale
# 474    Martin Morrissey          Mortehoe

# %%
df1.loc[df1['first_name']=='Erasmo','email']
# Out:
# 233    erasmo.talentino@hotmail.com
# 393               egath@hotmail.com
# 474         erasmo_rhea@hotmail.com
# Name: email, dtype: object

# %%
df1.loc[df1['first_name']=='Erasmo',['email','last_name']]
# Out:
#                             email  last_name
# 233  erasmo.talentino@hotmail.com  Talentino
# 393             egath@hotmail.com       Gath
# 474       erasmo_rhea@hotmail.com       Rhea

# %%
df1.loc[df1['first_name'] == 'Antonio', 'city':'first_name']
# Out:
# Empty DataFrame
# Columns: []
# Index: [272, 285, 427]

# %%
em = df1.loc[df1['email'].str.endswith(".com")] 
em2 = df1.loc[df1['email'].str.startswith("france")]
em2
# Out:
#   first_name last_name         company_name       address  \
# 2     France   Andrade  Elliott, John W Esq  8 Moor Place
#
#                              city       county   postal        phone1  \
# 2  East Southbourne and Tuckton W  Bournemouth  BH6 3BE  01347-368222
#
#          phone2                       email                               web  \
# 2  01935-821636  france.andrade@hotmail.com  http://www.elliottjohnwesq.co.uk
#
#     id
# 2  246

# %%
em.shape
# Out:
# (367, 12)

# %%
df1.loc[df1['first_name'].isin(['France', 'Tyisha', 'Eric'])]
# Out:
#   first_name last_name             company_name            address  \
# 2     France   Andrade      Elliott, John W Esq       8 Moor Place
# 4     Tyisha    Veness           Champagne Room  5396 Forth Street
# 5       Eric     Rampy  Thompson, Michael C Esq       9472 Lind St
#
#                              city            county    postal        phone1  \
# 2  East Southbourne and Tuckton W       Bournemouth   BH6 3BE  01347-368222
# 4      Greets Green and Lyng Ward     West Midlands   B70 9DT  01547-429341
# 5                      Desborough  Northamptonshire  NN14 2GH  01969-886290
#
#          phone2                       email  \
# 2  01935-821636  france.andrade@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
# 5  01545-817375          erampy@rampy.co.uk
#
#                                     web   id
# 2      http://www.elliottjohnwesq.co.uk  246
# 4        http://www.champagneroom.co.uk  627
# 5  http://www.thompsonmichaelcesq.co.uk  717
